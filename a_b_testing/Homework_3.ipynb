# %% [markdown]
# <a href="https://colab.research.google.com/github/eTcilopp/temp_python_intro_course_gb/blob/master/a_b_testing/Homework_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Настроить а/б тест на сайте с 3-мя изменениями

# %% [markdown]
# Решение.<br>
# Загрузил одностраничный сайт на github (https://etcilopp.github.io/)<br>

# %% [markdown]
# Настроил A/B эксперимент в Yandex Metrika<br>

# %% [markdown]
# ![AB Experiment Sert Up.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Проверил результат работы<br>

# %% [markdown]
# ![AB Experiment Sert Up.jpg]![AB_Experiment.jpg](data:image/jpeg;base64,...)
