# %% [markdown]
# # Домашнее задание 4

# %% [markdown]
# ## Задача 1
# Постройте график<br>
# Назовите график<br>
# Сделайте именование оси x и оси y<br>
# Сделайте выводы<br>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Скачиваем данные

# %%
house_data_df = pd.read_csv(r'C:\temp\kc-house-data (1).csv', encoding='ISO-8859-1')
laptop_data_df = pd.read_csv(r'C:\temp\laptop_price (1).csv', encoding='ISO-8859-1')

# %% [markdown]
# ### 1.2 Изучаем данные по стоимости недвижимости

# %%
fig = plt.figure(figsize=(10, 8))

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.4, 0.5, 0.4, 0.3])

axes1.ticklabel_format(useOffset=False, style='plain')

axes1.set_xlabel('Цена')
axes1.set_ylabel('Количество домов')
axes1.set_title('Гистограмма цен')

axes2.set_xlabel('Цена')
axes2.tick_params(labelleft=False, rotation=30)
axes2.set_title('BoxPlot')

axes2.ticklabel_format(useOffset=False, style='plain')


axes1.hist(house_data_df['price'], bins=20)
axes2.boxplot(house_data_df['price'],0,'s',0);

# %% [markdown]
# ## Выводы
# - в Калифорнии довольно много *относительно* дешевых домов, но все они мне не по-карману.
# - на удивление мало супер дорогих домов: буквально единицы все, что больше 4000000. А где же дома всех кинозвезд и воротил силиконовой долины??

# %% [markdown]
# ### 1.3. Изучаем распределение квадратуры жилой площади

# %%
fig = plt.figure(figsize=(10, 8))

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.4, 0.5, 0.4, 0.3])


axes1.grid(linewidth=1, axis='both', alpha=0.5)

axes1.set_xlabel('Площадь, кв. футы')
axes1.set_ylabel('Количество домов')
axes1.set_title('Гистограмма распределения площадей')

large_houses_sub_dataseries = house_data_df[house_data_df['sqft_living'] > 8000]['sqft_living']
axes2.set_xlabel('Площадь, кв. футы')
axes2.set_ylabel('Количество домов')
axes2.set_title('Очень большие дома')


axes1.hist(house_data_df['sqft_living'], bins=30)
axes2.hist(large_houses_sub_dataseries, bins=30);

# %% [markdown]
# ### 1.4. Изучаем распределение года постройки

# %%
fig = plt.figure(figsize=(10, 8))

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.grid(linewidth=1, axis='both', alpha=0.5)

axes.set_xlabel('Год постройки')
axes.set_ylabel('Количество домов')
axes.set_title('Гистограмма распределения годов постройки')

axes.hist(house_data_df['yr_built'], bins=30);

# %% [markdown]
# # Задача 2
# 2.1. Изучите распределение домов от наличия вида на набережную<br>
# Постройте график<br>
# Сделайте выводы<br>
# 2.2. Изучите распределение этажей домов<br>
# 2.3. Изучите распределение состояния домов<br>

# %%
data = house_data_df['waterfront'].value_counts()
data.index = ['no', 'yes']
data
# Out:
# no     21450
# yes      163
# Name: waterfront, dtype: int64

# %%
plt.figure(figsize=(6, 4))

plt.pie(data, autopct='%1.1f%%')

plt.title('Доля домов с видом на набережную')
plt.legend(data.index);

# %%
data = house_data_df.groupby('waterfront')['price'].agg(median_price='median').reset_index()
data.index = ['Нет', 'Есть']
data
# Out:
#       waterfront  median_price
# Нет            0      450000.0
# Есть           1     1400000.0

# %%
fig = plt.figure(figsize=(10, 8))

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.grid(linewidth=1, axis='both', alpha=0.5)
axes.ticklabel_format(useOffset=False, style='plain')


axes.set_xlabel('Вид на воду')
axes.set_ylabel('Цена')
axes.set_title('Зависимость цены от наличия вида на воду')

axes.bar(data.index, data['median_price']);

# %% [markdown]
# ## 2.2. Распределение этажей домов

# %%
data = house_data_df.groupby('yr_built')['floors'].agg(median_floors='median').reset_index()

# %%
fig = plt.figure(figsize=(10, 8))

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.grid(linewidth=1, axis='both', alpha=0.5)

axes.set_xlabel('Год постройки')
axes.set_ylabel('Среднее количество этажей')
axes.set_title('Гистограмма распределения годов постройки')

axes.bar(data['yr_built'], data['median_floors']);

# %% [markdown]
# ## Выводы:
# - старые дома обычно имеют от 1 до 2х этажей<br>
# - вплоть до середины 80-х годов в Калифорнии строили одноэтажные "бунгало"<br>
# - с 90-х и до наших дней стандарт для Калифорнии - 3 этажа для индивидуального дома.

# %% [markdown]
# ## 2.3. Изучите распределение состояния домов

# %%
sns.jointplot(y=house_data_df['price'], x=house_data_df['condition'], kind='reg');
plt.xlabel('Состояние дома')
plt.ylabel('Цена дома')
plt.ticklabel_format(useOffset=False, style='plain')
plt.show()

# %%
data = house_data_df.groupby('yr_built')['condition'].agg(median_condition='median').reset_index()

# %%
plt.bar(data['yr_built'],data['median_condition'])
plt.xlabel('Год постройки')
plt.ylabel('Среднее состояние дома')
plt.title('Состояния домов в зависимости от года постройки')
plt.show();

# %%
plt.hist(house_data_df['condition'])
plt.xlabel('Количество домов')
plt.ylabel('Состояние дома')
plt.title('Гистограмма состояний домов')
plt.show()

# %% [markdown]
# ## Выводы
# - больше всего домов с состоянием "3" (среднее)<br>
# - плохих и очень плохих домов мало<br>
# - старых домов в хорошем состоянии больше, чем новых. Очевидно, разучились строить.

# %% [markdown]
# # Задача 3
#
# - Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.<br>
# - Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %% [markdown]
# Для начала давайте построим матрицу корреляций, чтобы выявить факторы, влияющие на цены

# %%
corr_matrix = house_data_df.corr()
corr_matrix = np.round(corr_matrix, 1)
corr_matrix[np.abs(corr_matrix) < 0.3] = 0

# %%
plt.figure(figsize=(10, 8))

sns.set(font_scale=1.4)

sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm')

plt.title('Матрица корреляций')
plt.tight_layout()
plt.show()

# %% [markdown]
# Проанализировав строку (или колонку) price, выявляем факторы с наибольшим влиянием на цену

# %%
corr_df = corr_matrix['price'].to_frame().reset_index()
corr_df.sort_values(by='price', ascending=False, inplace=True)
corr_df = corr_df[(corr_df['price'] < 1) & (abs(corr_df['price']) > 0.5)]
corr_df.rename(columns={'index': 'factor', 'price': 'influence'}, inplace=True)
corr_df
# Out:
#            factor  influence
# 10          grade        0.7
# 4     sqft_living        0.7
# 18  sqft_living15        0.6
# 11     sqft_above        0.6

# %% [markdown]
# Построим графики для более детального изучения корреляции

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
plt.tight_layout()

for idx, axe in enumerate([axe for row in axes for axe in row]):
    factor = corr_df.iloc[idx]['factor']
    axe.set_title(factor)
    plt.ticklabel_format(useOffset=False, style='plain')
    axe.bar(house_data_df[factor], house_data_df['price'])

# %% [markdown]
# Рассмотрим, как общая оценка дома (grade) влияет на цену

# %%
sns.jointplot(x=house_data_df['grade'], y=house_data_df['price'], kind='reg')
plt.ticklabel_format(useOffset=False, style='plain')
plt.xlabel('Общая оценка дома')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# Выводы:<br>
# - ожидаемо, чем лучше дом, тем выше цена<br>
# - нижняя граница цен "отзывается" медленнее на рост оценки. Т.е. можно найти лучший дом за те же деньги!
# - домов с самой высокой оценкой мало, цены запредельно высоки. Вероятно, это какой-то эксклюзив.

# %% [markdown]
# Рассмотрим Влияние общей площади на цену дома

# %%
sns.jointplot(x=house_data_df['sqft_living'], y=house_data_df['price'], kind='reg')
plt.ticklabel_format(useOffset=False, style='plain')
plt.xlabel('Жилая площадь')
plt.ylabel('Цена')
plt.show();

# %% [markdown]
# Здесь зависимость менее яркая. <br>
# Можно посмотреть на зависимость цены квадратного фута в зависимости от общей площади

# %%
house_data_df['price_per_sq_foot'] = house_data_df['price']/house_data_df['sqft_living']

# %%
sns.jointplot(x=house_data_df['sqft_living'], y=house_data_df['price_per_sq_foot'], kind='reg')
plt.xlabel('Общая жилая площадь')
plt.ylabel('Цена за кв. фут')
plt.show();

# %% [markdown]
# Зависимость неявная - цена за квадратный фут может быть любой, лишь просматривается общая зависимость: чем больше дом, тем дешевле квадратный фут

# %% [markdown]
# Возьмем среднюю цену за фут в разбивке по общей оценке дома

# %%
data = house_data_df.groupby('grade')['price_per_sq_foot'].agg(median_sqft_price='median').reset_index()
plt.bar(data['grade'], data['median_sqft_price'])
plt.xlabel('Общая оценка дома')
plt.ylabel('Цена за кв. фут')
plt.show();

# %% [markdown]
# Наблюдается интересный феномен: дешевле всего покупать дома со средней оценкой.<rb>
# Удивительно также, что некоторые дома с плохой оценкой стоят дороже лучших домов (в пересчете на кв фут)

# %% [markdown]
# Оптимально покупать дома с оценкой 6 и выше и с ценой за кв. фут не более 275 долл

# %%
data = house_data_df[(house_data_df['grade'] >= 6) & (house_data_df['price_per_sq_foot'] <= 250)][['lat', 'long']]
data.rename(columns={'lat': 'latitude', 'long': 'longitude'}, inplace=True)

# %%
from shapely.geometry import Point

# %%
data['geometry'] = data.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
data
# Out:
#        latitude  longitude                  geometry
# 0       47.5112   -122.257  POINT (-122.257 47.5112)
# 1       47.7210   -122.319   POINT (-122.319 47.721)
# 2       47.7379   -122.233  POINT (-122.233 47.7379)
# 5       47.6561   -122.005  POINT (-122.005 47.6561)
# 6       47.3097   -122.327  POINT (-122.327 47.3097)
# ...         ...        ...                       ...
# 21603   47.5389   -121.881  POINT (-121.881 47.5389)
# 21605   47.5137   -122.167  POINT (-122.167 47.5137)
# 21608   47.6993   -122.346  POINT (-122.346 47.6993)
# 21609   47.5107   -122.362  POINT (-122.362 47.5107)
# 21611   47.5345   -122.069  POINT (-122.069 47.5345)
#
# [11193 rows x 3 columns]

# %%
data.plot(column='Geometry')
# geo_df.plot(column="Type", ax=ax, legend=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-fcc42a743e69> in <module>
# ----> 1 data.plot(column='Geometry')
#       2 # geo_df.plot(column="Type", ax=ax, legend=True)
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1188                 stacking_id=stacking_id,
#    1189                 is_errorbar=is_errorbar,
# -> 1190                 **kwds,
#    1191             )
#    1192             self._append_legend_handles_labels(newlines[0], label)
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1209             cls._initialize_stacker(ax, stacking_id, len(y))
#    1210         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1211         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1212         cls._update_stacker(ax, stacking_id, y)
#    1213         return lines
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         with pandas_converters():
# ---> 87             return func(*args, **kwargs)
#      88
#      89     return wrapper
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     709             # prevent style kwarg from going to errorbar, where it is unsupported
#     710             args = (x, y, style) if style is not None else (x, y)
# --> 711             return ax.plot(*args, **kwds)
#     712
#     713     def _get_index_name(self) -> str | None:
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1065                     func = getattr(self, f"set_{k}", None)
#    1066                     if not callable(func):
# -> 1067                         raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                              f"has no property {k!r}")
#    1069                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'column'

# %%
import folium
this_map = folium.Map(prefer_canvas=True)

def plotDot(point):
    folium.CircleMarker(
        location=[point['latitude'], point['longitude']],
        radius=2,
        popup=point.median_house_value
    ).add_to(this_map)
    
data.apply(plotDot, axis=1)

this_map.fit_bounds(this_map.get_bounds())

this_map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-0b198051721e> in <module>
#       9     ).add_to(this_map)
#      10
# ---> 11 data.apply(plotDot, axis=1)
#      12
#      13 this_map.fit_bounds(this_map.get_bounds())
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-95-0b198051721e> in plotDot(point)
#       6         location=[point['latitude'], point['longitude']],
#       7         radius=2,
# ----> 8         popup=point.median_house_value
#       9     ).add_to(this_map)
#      10
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'median_house_value'

# %%
data['geometry'].iloc[0].latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-3dceac1d44d1> in <module>
# ----> 1 data['geometry'].iloc[0].latitude
#
# AttributeError: 'Point' object has no attribute 'latitude'

# %%
data['geometry'].to_frame().apply(plotDot, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-b59db882192d> in <module>
# ----> 1 data['geometry'].to_frame().apply(plotDot, axis=1)
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-82-f4872453ad25> in plotDot(point)
#       4 def plotDot(point):
#       5     folium.CircleMarker(
# ----> 6         location=[point.latitude, point.longitude],
#       7         radius=2,
#       8         popup=point.median_house_value
#
# c:\users\alexander\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'latitude'
